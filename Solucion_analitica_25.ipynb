# %% [markdown]
# <a href="https://colab.research.google.com/github/GusBarcenac/Simulacion2-Examen-1/blob/main/Solucion_analitica_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **SOLUCION ANALITICA DEL EJERCICIO 25**
# Un quiosquero vende periódicos a 1.10 euros cada uno. Cada periódico le cuesta al quiosquero 0.90 euros. Las ventas de periódicos del quiosquero a partir de su expe-
# riencia se refleja en la tabla siguiente.
#
# ![1.1.png](data:image/png;base64,...)
#
# La tabla recoge por ejemplo que el 20 % del tiempo las ventas han sido de 30 periódicos. Teniendo en cuenta el coste de 0,20 euros por venta perdida y el coste de 0,10 euros por el reciclaje de cada periódico no vendido, determine el beneficio promedio diario si pide 50 periódicos cada día.
#
# **SOLUCION:**
#
# PASO 1. Defina las variables que intervienen en el modelo
# VENTA DE PERIODICOS
#
# PASO.2 Formule la distribución de probabilidad de cada variable a partir de los datos historicos
#
# ![1.2.png](data:image/png;base64,...)
#
# PASO 3. Enumere la distribución acumulada de la probabilidad de cada variable
#
# ![1.3.png](data:image/png;base64,...)
#
# PASO 4. Establezca el intervalo de numeros aleatorios correspondientes a cada valor de cada una de las variables.
# ![1.4.png](data:image/png;base64,...)
#
# PASO 5. Genere numeros aleatorios:
# 0.86,0.95,0.19,0.30,0.48,0.24,0.97,0.52,0.93,0.24
#
# PASO 6. Simule las ventas de un día y calcule el beneficio proporcionado por dichas ventas
#
# ![1.5.png](data:image/png;base64,...)
#
# Si ventas simuladas > pedido
# ventas reales = pedido
#
# ventas perdidas = ventas simuladas - pedidos
#
# periodicos no vendidos = 0
#
#
# Si ventas simuladas =< pedido
# Ventas reales = ventas simuladas
#
# ventas perdidas = 0
#
# periodicos no vendidos = pedido  - ventas reales
#
# Beneficio = (precio unitario de venta x ventas reales) - (coste unitario de adquisición x pedido) - (coste unitario de reciclaje x periodicos no vendidos) - (coste venta perdida x ventas perdidas)
#
# PASO 7. Repita el paso 6 nueve días más.
# ![1.6.png](data:image/png;base64,...)
#
# PASO 8. Obtenemos la gradica con la ayuda de las tablas en excel. Simulamos 500 días
#
# ![1.7.png](data:image/png;base64,...)
#
# PASO 9. Replicamos el modelo 40  veces y obtenemos
#
# ![1.8.png](data:image/png;base64,...)
#
# ![1.9.png](data:image/png;base64,...)
#
# PASO 10. Calculamos el beneficio medio diario y su desviciación estantar utilizando
#
# ![1.10.png](data:image/png;base64,...)
#
# PASO 11. Halle el intervalode confianza del beneficio medio diario con el nivel de aceptación del 95%
#
# ![1.11.png](data:image/png;base64,...)
#
# Si realilza 100 veces el modelo, el beneficio medio diario en el 95% de los dias se espera que ase encuentre en [0.72,2.27].
