# %% [markdown]
# <a href="https://colab.research.google.com/github/GusBarcenac/Simulacion2-Examen-1/blob/main/Soluci%C3%B3n_analitica_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **SOLUCION ANALITICA DEL EJERCICIO 26**
#
# Una empresa dispone de varias máquinas herramienta cuyas herramientas de corte se desgastan constantemente. Cuando esto ocurre, la máquina es inservible. En la actualidad el mantenimiento es correctivo reemplazándose una herramienta cuando falla. Dado que cada máquina dispone de una torre con cinco herramientas, se propone reemplazar toda la torre de herramientas (las cinco herramientas de golpe) cada vez que falle una, lo que debería reducir la frecuencia de desgaste de las herramientas. El tiempo necesario para el reemplazo de una herramienta es de una hora. Las cinco pueden reemplazarse en dos horas. El coste de una hora de máquina parada es de cien euros. Cada herramienta cuesta diez euros. La tabla siguiente recoge los datos de averías en el caso de sustituir una sola herramienta cada vez.
# ![2.000.png](data:image/png;base64,...)
#
# Si las cinco herramientas se cambian cada vez que una falla, la distribución de probabilidad entre fallos es la siguiente:
#
# ![2.001.png](data:image/png;base64,...)
#
# a) Determine mediante simulación la mejor política de reemplazo de las herramientas de corte.
#
# b) Resuelva el caso sin el uso de la simulación y compare los resultados. Indique si esto afecta o no a la decisión tomada utilizando la simulación.
#
#
#
# ---
#
#
# SOLUCION:
#
# PASO 1. Defina las variables qie intervienen en el modelo:Las horas entre averías.
#
# PASO 2. Formule la distribución de probabilidad de cada variable a partir de los datos historicos.
#
# ![2.01.png](data:image/png;base64,...)
#
# PASO 3. Enumere la distribución acumulada de probabilidad de cada variable.
#
# ![2.02.png](data:image/png;base64,...)
#
# PASO 4. Establezca el intervalo de numeros aleatirios correspondientes a cada valor de cada una de las variables
#
# ![2.03.png](data:image/png;base64,...)
#
# PASO 5. Genere numeros aleatorios:0.47,0.48,0.15,0.67,0.94
#
# PASO 6. Simule una variable y calcule el coste por hora de funcionamiento
#
# ![2.04.png](data:image/png;base64,...)
#
# Coste reemplazo = coste máquina parada + coste herramienta
#
# Coste reemplazo = 100 + 10 = 110 Euros
#
# ![2.05.png](data:image/png;base64,...)
#
# PASO 7. Repita el paso 6 con los numeros aletorios generados en el paso 5 y oobtenemos:
#
# ![2.06.png](data:image/png;base64,...)
#
# PASO 8. Obtenemos la grafica (recordemos quw differentes reperticiones del modelo dan resultados distintos)
#
# ![2.07.png](data:image/png;base64,...)
#
# PASO 9. Replicamos el modelo cuarenata veces y obtenemos 40 calores de coste por hora y graficamos.
#
# ![2.08.png](data:image/png;base64,...)
#
# ![2.09.png](data:image/png;base64,...)
#
# PASO 10. Calculo de coste por hora de funcionamiento y su desviaación estandar con las siguientes formulas
#
#
# ![2.010.png](data:image/png;base64,...)
#
# PASO 11. Encontramos el intervalo de confianza del coste por hora de funcionamiento con un nivel de aceptación del 95%.
#
# ![2.011.png](data:image/png;base64,...)
#
# Si se realizan 100 repeticiones del modelo, el coste por h/funciomienato en el 95% de las veces se espera quw se encuentre entre [1.95,2.25] euros por hora.
#
#
#
# ---
#
# *SUSTITUCION DE LA TORRE DE CINCO HERRAMIENTAS**
#
# PASO 1. Defina las variables que intervienen en el modelo: Las horas entre averías
#
# PASO 2. Formule la distribución de probabilidad de cada variable a partir de los datos históricos
#
# ![3.01.png](data:image/png;base64,...)
#
# PASO 3. Enumere la distribució acumulada de probabilidad de cada variable
#
# ![3.02.png](data:image/png;base64,...)
#
# PASO 4. Establecemos el intervalo de numeros aleatorios correspondientes a cada valorde cada una de las variables
#
# ![3.03.png](data:image/png;base64,...)
#
# PASO 5. Generamos numeros aleatorios:0.47,0.48,0.15,0.67,0.94
#
# PASO 6. Simule una avería y calcule el coste de reemplazar la herramienta
#
# ![3.04.png](data:image/png;base64,...)
#
# Coste reemplazo = coste maquina parada + coste herramienta
#
# coste mauina parada = 100 euro/hora x 2 = 200 euros
#
# coste herramientas = 100 euros/herraminetas x 5 = 50 euros
#
# coste reeplazo = 200 + 50 = 250 euros
#
#
# ![3.05.png](data:image/png;base64,...)
#
# PASO 7. Repita el paso 6 con los numeros aletorios del paso 5, obteniendo así
#
# ![3.06.png](data:image/png;base64,...)
#
# PASO 8. Obtenemos la grafica
#
# ![3.07.png](data:image/png;base64,...)
#
# PASO 9. Replicamos el modelo cuarenta veces
#
# ![3.08.png](data:image/png;base64,...)
#
# Y graficamos
#
# ![3.09.png](data:image/png;base64,...)
#
# PASO 10. Calculamos el coste por hora de funcionamiento y su desviación estándar de la sig. manera![3.010.png](data:image/png;base64,...)
#
# PASO 11. Encontramos el intervalo de confianza del coste por hora de funcionamiento con 95% de aceptación
#
# ![3.011.png](data:image/png;base64,...)
#
# Si realizamos 100 repeticiones del modelo, el coste por hora de funionacmiento en el 95% de ellas se encuentran en [3.78,4.22] euros por hora de funcionamiento. Concluimos que la politica de reemplazar una herramienta cuando se deteriore es la óptima.
